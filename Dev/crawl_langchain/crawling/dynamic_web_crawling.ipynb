# %% [markdown]
# # 동적 웹크롤링

# %% [markdown]
# ## selenium 소개 및 기초사용법

# %% [markdown]
# selenium 패키지는 chromedriver를 제어하거나 원하는 정보를 얻기 위해 사용합니다.
# 크롤링을 하다보면 무엇인가 입력하거나 특정 버튼을 눌러야 하는 상황에 사람 대신 컴퓨터가 할 수 있도록 해줍니다.
#
# !pip install selenium

# %% [markdown]
# ### 관련 패키지 import

# %%
# selenium의 webdriver를 사용하기 위한 import
from selenium import webdriver

# selenium으로 키를 조작하기 위한 import
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# 페이지 로딩을 기다리는데에 사용할 time 모듈 import
import time

# %% [markdown]
# ### 크롬 드라이버 실행

# %%
# 크롬드라이버 실행
driver = webdriver.Chrome() 

#크롬 드라이버에 url 주소 넣고 실행
driver.get('https://www.google.co.kr/')

# 페이지가 완전히 로딩되도록 3초동안 기다림
time.sleep(3)

# %% [markdown]
# ##  selenium으로 화면 조작하기

# %% [markdown]
# <개념>
# 1) 조작을 원하는 버튼이나 입력창의 html을 파악
#
# 2) 아래의 두 함수에 html 정보를 입력해서 객체(버튼/입력창 등) 선택
# - find_element(By.ID)
# - find_element(By.CLASS_NAME)
# - find_element(By.XPATH)
# - find_element(By.CSS_SELECTOR)
#
# 3) 기능 동작 관련 함수로 원하는 기능 조작
# - 클릭 : .click( )
# - 키 입력: .send_keys( )

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# # 위에서 실행한 코드

# # selenium의 webdriver를 사용하기 위한 import
# from selenium import webdriver

# # selenium으로 무엇인가 입력하기 위한 import
# from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.common.by import By

# # 페이지 로딩을 기다리는데에 사용할 time 모듈 import
# import time

# # 크롬드라이버 실행
# driver = webdriver.Chrome() 

# #크롬 드라이버에 url 주소 넣고 실행
# driver.get('https://www.google.co.kr/')

# # 페이지가 완전히 로딩되도록 3초동안 기다림
# time.sleep(3)

# %%
# 검색어 창을 찾아 search 변수에 저장 (By.CLASS_NAME 방식)
search_box_by_class = driver.find_element(By.CLASS_NAME, 'gLFyf') # class명이 gLFyf gsfi와 같이 빈칸이 존재하는 경우는 빈칸을 점(.)으로 변경해주지 않으면 원하는 정보를 제대로 찾지 못합니다. 즉, 클래스명을 gLFyf.gsfi라고 입력해주어야 합니다.

# 검색어 창을 찾아 search 변수에 저장 (By.XPATH 방식)
search_box = driver.find_element(By.XPATH, '//*[@id="APjFqb"]')
search_box == search_box_by_class
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
search_box.send_keys('파이썬')
search_box.send_keys(Keys.RETURN)
time.sleep(1)

# %%
# click 함수는 ()안에 아무것도 넣지 않으면 좌클릭을 수행

search_box = driver.find_element(By.XPATH, '//*[@id="APjFqb"]')
search_button = driver.find_element(By.XPATH, '//*[@id="tsf"]/div[1]/div[1]/div[2]/button')
search_box.send_keys('머신러닝')
search_button.click()
time.sleep(1)

# %% [markdown]
# ## 텍스트, 하이퍼링크, 이미지 가져오기

# %%
#step1.selenium 패키지와 time 모듈 import
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

#step2.검색할 키워드 입력
query = input('검색할 키워드를 입력하세요: ')

#step3.크롬드라이버로 원하는 url로 접속
url = 'https://www.naver.com/'
driver = webdriver.Chrome()
driver.get(url)
time.sleep(3)

#step4.검색창에 키워드 입력 후 엔터
search_box = driver.find_element(By.ID, "query")
search_box.send_keys(query)
search_box.send_keys(Keys.RETURN)
time.sleep(2)

#step5.뉴스 탭 클릭
driver.find_element(By.XPATH, '//*[@id="lnb"]/div[1]/div/div[1]/div/div[1]/div[3]/a').click()
time.sleep(2)

# %%
#step6.뉴스 제목 텍스트 추출 / .text

news_titles = driver.find_elements(By.CLASS_NAME, "news_tit")

for i in news_titles:
    title = i.text
    print(title)
# Out:
# LG생활건강 더후, 中징둥닷컴 스타어워즈 수상
# NH농협생명, 특약 강화한 '백세팔팔NH건강보험' 개정 출시
# 삼선산 수목원 숲에서 건강 찾아요~
# LG생활건강 더후, '비첩 NAD+ 심포지엄' 개최..."글로벌 공략"
# 빅스 혁, 오늘(18일) 훈련소 입소.."성숙하고 건강한 모습으로 복귀"[공식]
# 건강검진으로 췌장암 조기 발견 될까?
# “빵 먹으면서 식단관리 가능”…건강 챙긴 베이커리 돌풍
# 한총리 "연내 장애인 건강보건관리계획 수립…공공일자리 확대"
# [1분건강] 봄철 야외활동 늘자 ‘사마귀’ 발생↑
# "'식단탄' 순서로 먹어요"…요즘 인기 MZ 다이어트 뭐길래 [건강!톡]

# %%
#step7.뉴스 하이퍼링크 추출 / .get_attribute('href')

for i in news_titles:
    href = i.get_attribute('href')
    print(href)
# Out:
# https://www.news1.kr/articles/5387269
# https://www.sedaily.com/NewsView/2D7YKX7S72
# https://www.newsis.com/view/?id=NISX20240418_0002703892&cID=10807&pID=10800
# http://www.wowtv.co.kr/NewsCenter/News/Read?articleId=A202404180084&t=NN
# http://www.osen.co.kr/article/G1112318945
# http://news.heraldcorp.com/view.php?ud=20240418050075
# https://www.mk.co.kr/article/10992553
# https://www.yna.co.kr/view/AKR20240418067400001?input=1195m
# https://zdnet.co.kr/view/?no=20240418092049
# https://www.hankyung.com/article/202404176520i

# %%
#step8.뉴스 썸네일 이미지 추출 / .get_attribute('src')

# 스크롤 내리기 (모든 썸네일 이미지 로딩을 위함)
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

time.sleep(2)

#뉴스 썸네일 이미지 다운로드
news_content_div = driver.find_elements(By.CLASS_NAME, 'news_contents')

news_thumbnail = []

for i in news_content_div:

    try:

        thumbnail = i.find_element(By.CLASS_NAME, "thumb")
        news_thumbnail.append(thumbnail)

    except:
        pass

link_thumbnail = [img.get_attribute('src') for img in news_thumbnail]

# 이미지 저장할 폴더 생성
import os

# path_folder의 경로는 각자 저장할 폴더의 경로를 적어줄 것
path_folder = '/Users/r2com/Desktop/kpopmap/crawling/img_download/'

if  not os.path.isdir(path_folder):
    os.mkdir(path_folder)

# 이미지 다운로드
from urllib.request import urlretrieve

i = 0

for link in link_thumbnail:
    if link.startswith('https://'):
        i += 1
        urlretrieve(link, path_folder + f'news_{i}.jpg')
        time.sleep(0.3)

# %%
link_thumbnail
# Out:
# ['https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F421%2F2024%2F04%2F17%2F7486338.jpg&type=f200_200&expire=2&refresh=true',
#  'https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F011%2F2024%2F04%2F18%2F4329471.jpg&type=f200_200&expire=2&refresh=true',
#  'https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F003%2F2024%2F04%2F18%2F12498476.jpg&type=f200_200&expire=2&refresh=true',
#  'https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F215%2F2024%2F04%2F18%2F1158101.jpg&type=f200_200&expire=2&refresh=true',
#  'https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F109%2F2024%2F04%2F18%2F5060441.jpg&type=f200_200&expire=2&refresh=true',
# ...

# %% [markdown]
# <참고>
# 별점 추출 get_attribute('style')

# %%
# i.get_attribute('style')
